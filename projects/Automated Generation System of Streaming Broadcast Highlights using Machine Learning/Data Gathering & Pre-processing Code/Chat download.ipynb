# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
import random as rd
from scipy.stats import ttest_1samp
from scipy.stats import ttest_ind
from sklearn.linear_model import LinearRegression
from pandas import DataFrame
from pandas import read_csv
from matplotlib import pyplot
import requests 
import json
import sys

# %% [markdown]
# ## 트위치 스트리머 풍월량
#
# ### 트위치 스트리밍 제목 : 원시인이 점프하는 게임 케이브맨 빅 점프 풍월량[2021.02.22] : https://www.twitch.tv/videos/924112733 / 유튜브 제목 : 할수록 빡치는 전설의 원시인 똥겜 켠왕ㅋㅋㅋㅋ 케이브맨 빅점프 [풍월량][2021.02.26]
#
# ### 트위치 스트리밍 제목 : 풍월량[2021.02.24] (6:01:24~12:17:48) : https://www.twitch.tv/videos/926484159 / 유튜브 제목 : [신작소개소] 귀여운 동물들과 함께하는 힐링 귀농게임 신작! 목장이야기: 올리브 타운과 희망의 대지

# %%
def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)

def main(v_id,c_id):   
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')    
    
    videoId = "924112733"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor          
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %%
# 트위치 생방송 채팅로그 추출하기 풍월량, videoID = 926484159

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "926484159"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# # 트위치 생방송 채팅로그 추출하기 풍월량, videoID = 924046724
#
# def doubleDigit(num):
#     if num < 10 :
#         return '0'+str(num)
#     else:
#         return str(num)
#
#
# def main(v_id,c_id):
#
#
#     if sys.version_info[0] == 2:
#         reload(sys)
#         sys.setdefaultencoding('utf-8')
#
#
#     videoId = "924046724"
#     clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
#
#
#
#     chat = []
#     time = []
#     user = []
#
#     nextCursor = ''
#
#     params = {}
#     params['client_id'] = clientId
#
#
#     i = 0
#
#     while True :
#         if i == 0 :
#             URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0'
#             i += 1
#         else:
#             URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor='
#             URL +=  nextCursor
#
#
#
#         response = requests.get(URL, params=params)
#
#         j = json.loads(response.text)
#
#         for k in range(0,len(j["comments"])):
#             timer = j["comments"][k]["content_offset_seconds"]
#
#             timeMinute = int(timer/60)
#
#             if timeMinute >= 60 :
#                 timeHour = int(timeMinute/60)
#                 timeMinute %= 60
#             else :
#                 timeHour = int(timeMinute/60)
#
#             timeSec = int(timer%60)
#
#             time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
#             user.append(j["comments"][k]["commenter"]["display_name"])
#             chat.append(j["comments"][k]["message"]["body"])
#
#         if '_next' not in j:
#             break
#
#         nextCursor = j["_next"]
#
#
#     f = open(videoId+".txt", 'wt', -1, "utf-8")
#
#     for x in range(0, len(time)):
#             f.write('')
#             f.write(str(time[x]))
#             f.write('')
#             f.write('|')
#             f.write('')
#             f.write(str(user[x]))
#             f.write('')
#             f.write('|')
#             f.write(str(chat[x]))
#             f.write("\n")
#
#     f.close()
#
#
# if __name__ == "__main__":
#     main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 트위치 스트리머 랄로  / 유튜브 제목:
#
# ### 트위치 스트리밍 제목 : 광고[2021.02.06] : https://www.twitch.tv/videos/903242294 / 유튜브 제목 : 모두의 마블 모야호[2021.02.09]

# %%
# 트위치 생방송 채팅로그 추출하기 랄로, videoID = 903242294
def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "903242294"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 트위치 스트리머 파카9999
#
# ### 트위치 스트리밍 제목 : 탑 으 로 캐 리 해[2021.02.19 트위치] : https://www.twitch.tv/videos/920049094 / 유튜브 제목 : 깊은 지성 탑솔러[2021.02.23 유튜브]
#
# ### 트위치 스트리밍 제목 : 파카 마스터 간다[2021.02.21 트위치] : https://www.twitch.tv/videos/922834094 / 유튜브 제목 : 서포터니까[2021.02.28 유튜브]

# %%
# 트위치 생방송 채팅로그 추출하기 파카9999 , videoID = 920049094

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "920049094"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %%
# 트위치 생방송 채팅로그 추출하기 파카9999 , videoID = 922834094

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "922834094"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 트위치 스트리머 괴물쥐123
#
# ### 트위치 스트리밍 제목 : 목표 마스터 100점[2021.03.03] : https://www.twitch.tv/videos/935176016/ 유튜브 제목 : 꿈을 꾸었습니다[2021.3.4]

# %%
# 트위치 생방송 채팅로그 추출하기 괴물쥐123 , videoID = 935176016

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "935176016"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 트위치 스트리머 얍얍
#
# ### 트위치 스트리밍 제목 : 0216[2021.02.16] : https://www.twitch.tv/videos/916232844 / 유튜브 제목 : 🔥얍르코프 2일 차 하이라이트🔥[2021.02.18]
#
# ### 트위치 스트리밍 제목 : 0218[2021.02.18] : https://www.twitch.tv/videos/918848624 / 유튜브 제목 : 🔥얍르코프 4일 차 하이라이트🔥[2021.02.20]

# %%
# 트위치 생방송 채팅로그 추출하기 얍얍 , videoID = 916232844

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "916232844"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %%
# 트위치 생방송 채팅로그 추출하기 얍얍 , videoID = 918848624

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "918848624"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 트위치 스트리머 우왁굳
#
# ### 트위치 스트리밍 제목 : 복귀 시험 방송\(05:04:02~7:34:02)[2021.03.05] : https://www.twitch.tv/videos/937608573 / 유튜브 제목 : 아니 얼마나 빡치게 할라고 게임 이름이 ALT F4야[2021. 3. 13]

# %%
# 트위치 생방송 채팅로그 추출하기 우왁굳 , videoID = 937608573

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "937608573"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 트위치 스트리머 앰비션
#
# ### 트위치 스트리밍 제목 : 강찬밥 쭉올립니다 [2021.03.05] : https://www.twitch.tv/videos/937548014 / 유튜브 제목 : 매드라이프를 능가하는 괴물 블리츠출현 [2021.03.07]

# %%
# 트위치 생방송 채팅로그 추출하기 앰비션 , videoID = 937548014

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "937548014"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 트위치 스트리머 소니쇼
#
# ### 트위치 스트리밍 제목 : 초고교급 의사양반[2021.03.08] : https://www.twitch.tv/videos/941561128 / 유튜브 제목 : 의사양반이 된 소니쇼[2021.03.13]
#
# ### 트위치 스트리밍 제목 : 로봇아니고사람인데로그인안시켜주냐[2021.02.14] : https://www.twitch.tv/videos/913699132 / 유튜브 제목 : 내 눈을 의심해!! 제작자는 천재다.. [ 슈퍼 리미널 ][2021.03.01]

# %%
# 트위치 생방송 채팅로그 추출하기 소니쇼 , videoID = 941561128

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "941561128"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %%
# 트위치 생방송 채팅로그 추출하기 소니쇼 , videoID = 913699132

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "913699132"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 트위치 스트리머 재슥짱
#
# ### 트위치 스트리밍 제목 : 운이없다 운이없어[2021.03.09] : https://www.twitch.tv/videos/942215773 / 유튜브 제목 : 멈춰!![2021.03.10]

# %%
# 트위치 생방송 채팅로그 추출하기 재슥짱 , videoID = 942215773

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "942215773"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 미라지
#
# ### 트위치 스트리밍 제목 : 두자릿수 까지 갑니다[2021.01.31] : https://www.twitch.tv/videos/895415119 / 유튜브 제목 : 대통령 등판함ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ - 오버워치 (Overwatch)[2021.02.03]
#
# ### 트위치 스트리밍 제목 : 오래못해욤,,,[2021.02.15] : https://www.twitch.tv/videos/914887347 / 유튜브 제목 : 대기열 우선권 강제로 환불 받았습니다. - 오버워치 (Overwatch)[2021.02.16]

# %%
# 트위치 생방송 채팅로그 추출하기 미라지 , videoID = 895415119

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "895415119"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-a40f2e87eba9> in <module>
#      88
#      89 if __name__ == "__main__":
# ---> 90     main(sys.argv[1],sys.argv[2])
#
# <ipython-input-2-a40f2e87eba9> in main(v_id, c_id)
#      47         j = json.loads(response.text)
#      48
# ---> 49         for k in range(0,len(j["comments"])):
#      50             timer = j["comments"][k]["content_offset_seconds"]
#      51
#
# KeyError: 'comments'

# %%
# 트위치 생방송 채팅로그 추출하기 미라지 , videoID = 895415119

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "895415119"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-a40f2e87eba9> in <module>
#      88
#      89 if __name__ == "__main__":
# ---> 90     main(sys.argv[1],sys.argv[2])
#
# <ipython-input-5-a40f2e87eba9> in main(v_id, c_id)
#      47         j = json.loads(response.text)
#      48
# ---> 49         for k in range(0,len(j["comments"])):
#      50             timer = j["comments"][k]["content_offset_seconds"]
#      51
#
# KeyError: 'comments'

# %%
# 트위치 생방송 채팅로그 추출하기 미라지 , videoID = 914887347

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "914887347"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-67b461aafbae> in <module>
#      88
#      89 if __name__ == "__main__":
# ---> 90     main(sys.argv[1],sys.argv[2])
#
# <ipython-input-6-67b461aafbae> in main(v_id, c_id)
#      47         j = json.loads(response.text)
#      48
# ---> 49         for k in range(0,len(j["comments"])):
#      50             timer = j["comments"][k]["content_offset_seconds"]
#      51
#
# KeyError: 'comments'

# %% [markdown]
# ## 트위치 스트리머 인간젤리
#
# ### 트위치 스트리밍 제목 : 안녕하세요 젤리입니당~[2021.02.23] : https://www.twitch.tv/videos/925275340 / 유튜브 제목 : [배그] 나한테 쌓인게 많았나보구나... - 젤피뉴 배그 합방 1부[2021.03.03] + [배그] 여기서 뭐라고 대답해야 함? - 젤피뉴 배그 합방 2부[2021.03.06]

# %%
# 트위치 생방송 채팅로그 추출하기 인간젤리 , videoID = 925275340

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "925275340"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 트위치 스트리머 이태준
#
# ### 트위치 스트리밍 제목 : 하위~[2021.02.16] : https://www.twitch.tv/videos/916331457 / 유튜브 제목 : 결말 미쳤다;; 현실 소름 돋는 찐공포게임(편집본)ㅣ리틀나이트메어2(Little Nightmares II)[2021.02.27]

# %%
# 트위치 생방송 채팅로그 추출하기 이태준 , videoID = 916331457

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "916331457"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 트위치 스트리머 치킨쿤
#
# ### 트위치 스트리밍 제목 : 🐔어? 이틀 연속 에펙? - 빅헤드 유키드[2021.02.18] : https://www.twitch.tv/videos/918712592 / 유튜브 제목 : 에펙 좀만 더 같이 하자고[2021.02.28]

# %%
# 트위치 생방송 채팅로그 추출하기 치킨쿤 , videoID = 918712592

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "918712592"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 트위치 스트리머 주키니TV
#
# ### 트위치 스트리밍 제목 : 주하[2021.03.05] : https://www.twitch.tv/videos/937786846 / 유튜브 제목 : 다시 돌아온 전설의 "원투송"[2021.03. 08] + 세상에서 오토바이를 가장 잘 타는 유튜버[2021.03.10]
#
# ### 트위치 스트리밍 제목 : 오랜만이에용[2021.03.09] : https://www.twitch.tv/videos/942840952 / 유튜브 제목 : 제가 임포스터에요 [어몽어스][2021.03.12]

# %%
# 트위치 생방송 채팅로그 추출하기 주키니TV , videoID = 937786846

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "937786846"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %%
# 트위치 생방송 채팅로그 추출하기 주키니TV , videoID = 942840952

def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "942840952"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write('|')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write('|')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## Just Chatting

# %% [markdown]
# ## 침착맨
# ## 트위치 스트리밍 제목: 2021년 3월 16일 침펄풍 모임 / 품 회원님은 3시부터 합류https://www.twitch.tv/videos/951164050
# ## 유튜브 제목: 2021년 3월 21일 눈 감고 탄산음료 7종 알아맞히기https://www.youtube.com/watch?v=biUg_AAys0M
#
# ## 트위치 스트리밍 제목: 2021년 3월 15일 과자 신제품 or 콜라보 시식회https://www.twitch.tv/videos/950031801
# ## 유튜브 제목: 2021년 3월 24일 신기한 과자 시식회https://www.youtube.com/watch?v=JRnc5_bsISo
#
# ## 트위치 스트리밍 제목: 2021년 3월 17일 길동시장 마늘떡볶이 먹방 https://www.twitch.tv/videos/952453866
# ## 유튜브 제목: 2021년 3월 22일 마법방어력이 올라가는 떡볶이와 계획된 일정들https://www.youtube.com/watch?v=POUlEbYTOpo

# %%
# 트위치 생방송 채팅로그 추출하기 침착맨 , videoID = 951164050


def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "951164050"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write(',')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write(',')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %%
# 트위치 생방송 채팅로그 추출하기 침착맨 , videoID = 950031801


def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "950031801"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write(',')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write(',')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-be756e3f37d8> in <module>
#      89
#      90 if __name__ == "__main__":
# ---> 91     main(sys.argv[1],sys.argv[2])
#
# <ipython-input-3-be756e3f37d8> in main(v_id, c_id)
#      44
#      45
# ---> 46         response = requests.get(URL, params=params)
#      47
#      48         j = json.loads(response.text)
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
# ...

# %%
# 트위치 생방송 채팅로그 추출하기 침착맨 , videoID = 952453866


def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "952453866"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write(',')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write(',')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 트위치 스트리머 랄로
#
# ### 트위치 스트리밍 제목 : 양지 게임 팀파이트 매니저[2021.03.07] : https://www.twitch.tv/videos/940531018 / 유튜브 제목 : 호주 워킹홀리데이 연습생 썰[2021.03.12]
#
# ### 트위치 스트리밍 제목 : 무지성 베인[2021.02.15] : https://www.twitch.tv/videos/915012913 / 유튜브 제목 : 포르쉐 풀옵션 계약했습니다[2021.02.19]

# %%
# 트위치 생방송 채팅로그 추출하기 랄로, videoID = 940531018


def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "940531018"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write(',')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write(',')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %%
# 트위치 생방송 채팅로그 추출하기 랄로, videoID = 915012913


def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "915012913"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write(',')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write(',')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %% [markdown]
# ## 꽈뚜룹
#
# ### 늦은밤 교촌리뷰 / 노가리[2021.03.26]: https://www.twitch.tv/videos/963825338 / 유튜브 교촌 신메뉴, 트러플 버섯 치킨 먹방 리뷰 ㅋㅋㅋㅋ[2021. 3. 28
#
# ### 해위[2021.03.24]: https://www.twitch.tv/videos/961365989 / 유튜브 BBQ 신메뉴, 체고치 치킨 먹방 리뷰 ㅋㅋㅋ[2021. 3. 26]

# %%
# 트위치 생방송 채팅로그 추출하기 꽈뚜룹, videoID = 963825338


def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "963825338"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write(',')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write(',')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])

# %%
# 트위치 생방송 채팅로그 추출하기 꽈뚜룹, videoID = 961365989


def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "961365989"
    clientId = "hxr989pss9azzdbzfrlwhwbcabjhp2"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    i = 0
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            user.append(j["comments"][k]["commenter"]["display_name"])
            chat.append(j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
            
    
    f = open(videoId+".txt", 'wt', -1, "utf-8")
    
    for x in range(0, len(time)): 
            f.write('')
            f.write(str(time[x]))
            f.write('')
            f.write(',')
            f.write('')
            f.write(str(user[x]))
            f.write('')
            f.write(',')
            f.write(str(chat[x]))
            f.write("\n")
            
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])
