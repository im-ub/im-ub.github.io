# %%
import pandas as pd
import numpy as np
import io   
import requests
import datetime as dt
import copy

# %%
data1 = pd.read_csv("[Final Window]괴물쥐_935176016.csv", encoding='CP949')
data2 = pd.read_csv("[Final Window]랄로_903242294.csv", encoding='CP949')
data3 = pd.read_csv("[Final Window]미라지_895415119.csv", encoding='CP949')
data4 = pd.read_csv("[Final Window]미라지_914887347.csv", encoding='CP949')
data5 = pd.read_csv("[Final Window]소니쇼_913699132.csv", encoding='CP949')
data6 = pd.read_csv("[Final Window]소니쇼_941561128.csv", encoding='CP949')
data7 = pd.read_csv("[Final Window]앰비션_937548014.csv", encoding='CP949')
data8 = pd.read_csv("[Final Window]얍얍_916232844.csv", encoding='CP949')
data9 = pd.read_csv("[Final Window]얍얍_918848624.csv", encoding='CP949')
data10 = pd.read_csv("[Final Window]우왁굳_937608573.csv", encoding='CP949')
data11 = pd.read_csv("[Final Window]이태준_916331457.csv", encoding='CP949')
data12 = pd.read_csv("[Final Window]인간젤리_925275340.csv", encoding='CP949')
data13 = pd.read_csv("[Final Window]재슥짱_942215773.csv", encoding='CP949')
data14 = pd.read_csv("[Final Window]주키니_937786846.csv", encoding='CP949')
data15 = pd.read_csv("[Final Window]주키니_942840952.csv", encoding='CP949')
data16 = pd.read_csv("[Final Window]치킨쿤_918712592.csv", encoding='CP949')
data17 = pd.read_csv("[Final Window]파카_922834094.csv", encoding='CP949')
data18 = pd.read_csv("[Final Window]풍월량_924112733.csv", encoding='CP949')
data19 = pd.read_csv("[Final Window]얍얍_918848624.csv", encoding='CP949')
data20 = pd.read_csv("[Final Window]풍월량_926484159.csv", encoding='CP949')

# %%
data = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12, data13, data14, data15, data16, data17, data18, data19])
data
# Out:
#              시간                                  채팅내용  \
# 0      00:00:00
# 1      00:00:01
# 2      00:00:02
# 3      00:00:03
# 4      00:00:04
# ...         ...                                   ...
# 41665  11:34:25              3주 에반데 그립습니다........ 3년임
# 41666  11:34:26             3주 에반데 그립습니다........ 3년임
# 41667  11:34:27  3주 에반데 그립습니다........ 3년임  수술들어간다는데..
# 41668  11:34:28                                   NaN
# 41669  11:34:29                                   NaN
#
#                              시청자ID 하이라이트 여부  채팅수      참여비율     시간정규화  어절수  \
# 0                                         X  0.0  0.000000  0.000034    0
# 1                                         X  0.0  0.000000  0.000069    0
# 2                                         X  0.0  0.000000  0.000103    0
# 3                                         X  0.0  0.000000  0.000138    0
# 4                                         X  0.0  0.000000  0.000172    0
# ...

# %%
#change_highlight = {'O':1, 'X':0}
data['하이라이트 여부'] = data['하이라이트 여부'].replace('O', '1')
data['하이라이트 여부'] = data['하이라이트 여부'].replace('X', '0')
data
# Out:
#              시간                                  채팅내용  \
# 0      00:00:00
# 1      00:00:01
# 2      00:00:02
# 3      00:00:03
# 4      00:00:04
# ...         ...                                   ...
# 41665  11:34:25              3주 에반데 그립습니다........ 3년임
# 41666  11:34:26             3주 에반데 그립습니다........ 3년임
# 41667  11:34:27  3주 에반데 그립습니다........ 3년임  수술들어간다는데..
# 41668  11:34:28                                   NaN
# 41669  11:34:29                                   NaN
#
#                              시청자ID 하이라이트 여부  채팅수      참여비율     시간정규화  어절수  \
# 0                                         0  0.0  0.000000  0.000034    0
# 1                                         0  0.0  0.000000  0.000069    0
# 2                                         0  0.0  0.000000  0.000103    0
# 3                                         0  0.0  0.000000  0.000138    0
# 4                                         0  0.0  0.000000  0.000172    0
# ...

# %%
data = data.drop(['시간','채팅내용', '시청자ID'], axis=1)

# %%
data = data.astype({'하이라이트 여부':'int', '채팅수':'float', '어절수':'float', '음절수':'float', '낱글자수':'float'})

# %%
data
# Out:
#        하이라이트 여부  채팅수      참여비율     시간정규화  어절수   음절수  낱글자수   채팅당 어절수  채팅당 음절수  \
# 0             0  0.0  0.000000  0.000034  0.0   0.0   0.0  0.000000     0.00
# 1             0  0.0  0.000000  0.000069  0.0   0.0   0.0  0.000000     0.00
# 2             0  0.0  0.000000  0.000103  0.0   0.0   0.0  0.000000     0.00
# 3             0  0.0  0.000000  0.000138  0.0   0.0   0.0  0.000000     0.00
# 4             0  0.0  0.000000  0.000172  0.0   0.0   0.0  0.000000     0.00
# ...         ...  ...       ...       ...  ...   ...   ...       ...      ...
# 41665         0  3.0  0.003194  0.999904  5.0  21.0   0.0  1.666667     7.00
# 41666         0  3.0  0.003194  0.999928  5.0  21.0   0.0  1.666667     7.00
# 41667         0  4.0  0.005405  0.999952  7.0  31.0   0.0  1.750000     7.75
# 41668         0  0.0  0.000000  0.999976  0.0   0.0   0.0  0.000000     0.00
# 41669         0  0.0  0.000000  1.000000  0.0   0.0   0.0  0.000000     0.00
#
#        채팅당 낱글자수  Hscore    Nscore
# ...

# %%
def make_dataset(data, label, window_size = 20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
feature_cols = ['채팅수','참여비율','시간정규화','어절수','음절수','낱글자수','채팅당 어절수','채팅당 음절수','채팅당 낱글자수','Hscore','Nscore']
label_cols = ['하이라이트 여부']

# %%
train_feature = data[feature_cols]
train_label = data[label_cols]

# %%
train_feature, train_label = make_dataset(train_feature, train_label, 20)

# %%
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size =0.2)
x_train.shape,x_valid.shape
# Out:
# ((391835, 20, 11), (97959, 20, 11))

# %%
test_feature = data[feature_cols]
test_label = data[label_cols]

# %%
test_feature.shape, test_label.shape
# Out:
# ((489814, 11), (489814, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import pandas as pd
import numpy as np
import keras
import tensorflow as tf
from numpy import array
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU
from keras.layers import Dense, Dropout
from keras.datasets import imdb
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.activations import sigmoid

# %%
# from keras. models import load_model
# model = load_model('modeL.h5')

# %%
# yhat = model.predict_classes(train_feature)

# %%
# yhat

# %%
# pred = pd.DataFrame(yhat)

# %%
# pred.to_csv('이름.csv', encoding = 'cp949')

# %%
from keras.models import load_model
model = load_model('LSTM.h5')

# %%
test_loss, test_acc = model.evaluate(x_train,y_train)
print('Test accuracy:',test_acc)
# Out:
# 12245/12245 [==============================] - 39s 3ms/step - loss: 0.1753 - accuracy: 0.9389
# Test accuracy: 0.9389258027076721

# %%
model = Sequential()
# model.add(GRU(128, input_shape=(train_feature.shape[1], train_feature.shape[2])))
model.add(LSTM(units = 128, input_shape=(train_feature.shape[1],train_feature.shape[2]),))
model.add(Dense(units = 32, activation='relu'))
model.add(keras.layers.Dense(1, activation='sigmoid')) #sigmoid
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


model.fit(x_train, y_train, epochs=10, batch_size=1)

test_loss, test_acc = model.evaluate(x_train,y_train)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/10
#  7724/97959 [=>............................] - ETA: 3:08 - loss: 0.3428 - accuracy: 0.8804
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-f454ccc1e560> in <module>
#       7
#       8
# ----> 9 model.fit(x_valid, y_valid, epochs=10, batch_size=1)
#      10
#      11 test_loss, test_acc = model.evaluate(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1156                 _r=1):
#    1157               callbacks.on_train_batch_begin(step)
# -> 1158               tmp_logs = self.train_function(iterator)
# ...

# %%
from keras.models import load_model
model.save('GRU.h5')

# %%
from keras.models import load_model
model = load_model('LSTM.h5')

# %%
paka = pd.read_csv('[Final Window]파카_920049094.csv', encoding = 'cp949')
paka
# Out:
#              시간                                               채팅내용  \
# 0      00:00:00                                                이거지
# 1      00:00:01                                               이거지
# 2      00:00:02                                              이거지
# 3      00:00:03
# 4      00:00:04
# ...         ...                                                ...
# 18997  05:16:37  다본거라고 ㅋㅋ 이미봤음 와 팍튜브 프리미엄도 있나요? 빠이 와난 오 같이 보죠 우...
# 18998  05:16:38  오 같이 보죠 우두르가 어케 벽을넘어 ㅋㅋ 와난 ㅋㅋ 아니 그건 20분짜리고 이건 ...
# 18999  05:16:39  와난 ㅋㅋ 아니 그건 20분짜리고 이건 5시간짜리잖아요 주인도광고보는킹튜부  어차피...
# 19000  05:16:40                                                NaN
# 19001  05:16:41                                                NaN
#
#                                                    시청자ID 하이라이트 여부   채팅수  \
# 0                                                콩쥐팥쥐괴물쥐        X   1.0
# 1                                               콩쥐팥쥐괴물쥐         X   1.0
# ...

# %%
paka_feature= ['채팅수','참여비율','시간정규화','어절수','음절수','낱글자수','채팅당 어절수','채팅당 음절수','채팅당 낱글자수','Hscore','Nscore']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-a7bae212ca05> in <module>
# ----> 1 paka = paka.drop(['하이라이트 여부'], axis = 1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
pred = model.predict_classes(train_feature)
pred
# Out:
# C:\Users\junho\anaconda3\lib\site-packages\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-5096cba4c974> in <module>
# ----> 1 pred = model.predict_classes(train_feature)
#       2 pred
#
# ~\anaconda3\lib\site-packages\keras\engine\sequential.py in predict_classes(self, x, batch_size, verbose)
#     457                   '  if your model does binary classification '
# ...

# %% [markdown]
# ##########

# %%
x_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-80784060c951> in <module>
# ----> 1 x_train
#
# NameError: name 'x_train' is not defined

# %%
mmscaler = MinMaxScaler()
mmscaler.fit(data)
# Out:
# MinMaxScaler()

# %%
data = data.to_numpy()
#data = data.values

# %%
X = data[0:, 1:12]
Y = data[0:, 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-822861a82b37> in <module>
# ----> 1 X = data[0:, 1:12]
#       2 Y = data[0:, 0]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2893             casted_key = self._maybe_cast_indexer(key)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#    2897                 raise KeyError(key) from err
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
X
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 2.40000000e+01, 1.47147147e-02, ...,
#         4.75416667e+01, 0.00000000e+00, 4.95867769e-03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])
